# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf
import plotly.express as px
import numpy as np
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from matplotlib import style

# %%
file = 'csv/NFLX.csv'

df = pd.read_csv(file)
df2 = df
df.drop(['Date'],axis=1,inplace=True)
df
# Out:
#            Open        High         Low       Close   Adj Close   Volume
# 0    363.000000  377.799988  361.170013  370.959991  370.959991  8622000
# 1    367.929993  383.010010  366.440002  375.500000  375.500000  9366500
# 2    376.049988  380.230011  361.019989  364.079987  364.079987  6672500
# 3    364.079987  370.989990  360.059998  370.079987  370.079987  4592500
# 4    367.470001  370.899994  357.510010  361.760010  361.760010  4860800
# ..          ...         ...         ...         ...         ...      ...
# 246  509.130005  529.309998  509.130005  523.109985  523.109985  3360600
# 247  529.869995  543.119995  529.400024  535.090027  535.090027  5583500
# 248  533.780029  534.419983  520.000000  520.809998  520.809998  4102200
# 249  516.989990  518.530029  497.000000  502.859985  502.859985  4926800
# 250  502.820007  508.720001  496.679993  508.049988  508.049988  3464200
#
# [251 rows x 6 columns]

# %%
X = df.drop('Close',axis=1)
y = df.Close

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict(x_test)
# Out:
# array([492.98999 , 497.519989, 473.079987, 539.809998, 508.890015,
#        532.390015, 488.23999 , 528.909973, 500.029999, 434.480011,
#        413.440002, 441.950012, 498.309998, 479.100006, 586.340027,
#        523.059998, 490.579987, 476.26001 , 519.780029, 530.869995,
#        436.25    , 552.159973, 556.780029, 414.329987, 431.820007,
#        488.809998, 524.830017, 556.52002 , 455.040009, 493.329987,
#        424.98999 , 527.51001 , 482.029999, 452.579987, 497.980011,
#        484.529999, 490.76001 , 488.929993, 495.98999 , 371.119995,
#        491.869995, 481.329987, 466.929993, 457.850006, 507.019989,
#        504.209991, 540.72998 , 361.76001 , 484.119995, 530.789978,
#        502.779999])

# %%
df
# Out:
#            Open        High         Low       Close   Adj Close   Volume
# 0    363.000000  377.799988  361.170013  370.959991  370.959991  8622000
# 1    367.929993  383.010010  366.440002  375.500000  375.500000  9366500
# 2    376.049988  380.230011  361.019989  364.079987  364.079987  6672500
# 3    364.079987  370.989990  360.059998  370.079987  370.079987  4592500
# 4    367.470001  370.899994  357.510010  361.760010  361.760010  4860800
# ..          ...         ...         ...         ...         ...      ...
# 246  509.130005  529.309998  509.130005  523.109985  523.109985  3360600
# 247  529.869995  543.119995  529.400024  535.090027  535.090027  5583500
# 248  533.780029  534.419983  520.000000  520.809998  520.809998  4102200
# 249  516.989990  518.530029  497.000000  502.859985  502.859985  4926800
# 250  502.820007  508.720001  496.679993  508.049988  508.049988  3464200
#
# [251 rows x 6 columns]

# %%
predictions = model.predict(df[['Open','High','Low','Adj Close','Volume']])

# %%
df['predicted'] = predictions

# %%
df
# Out:
#            Open        High         Low       Close   Adj Close   Volume  \
# 0    363.000000  377.799988  361.170013  370.959991  370.959991  8622000
# 1    367.929993  383.010010  366.440002  375.500000  375.500000  9366500
# 2    376.049988  380.230011  361.019989  364.079987  364.079987  6672500
# 3    364.079987  370.989990  360.059998  370.079987  370.079987  4592500
# 4    367.470001  370.899994  357.510010  361.760010  361.760010  4860800
# ..          ...         ...         ...         ...         ...      ...
# 246  509.130005  529.309998  509.130005  523.109985  523.109985  3360600
# 247  529.869995  543.119995  529.400024  535.090027  535.090027  5583500
# 248  533.780029  534.419983  520.000000  520.809998  520.809998  4102200
# 249  516.989990  518.530029  497.000000  502.859985  502.859985  4926800
# 250  502.820007  508.720001  496.679993  508.049988  508.049988  3464200
#
#       predicted
# 0    370.959991
# 1    375.500000
# 2    364.079987
# 3    370.079987
# 4    361.760010
# ..          ...
# 246  523.109985
# 247  535.090027
# 248  520.809998
# 249  502.859985
# 250  508.049988
#
# [251 rows x 7 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Close'])
plt.plot(df['predicted'])
plt.legend(['Close','Predicted'])
plt.show()

# %% [markdown]
# # FROM ABOVE PLOT WE CAN SEE THAT OUR MODEL IS 100% ACCURATE ,THE LINES OVERLAP
